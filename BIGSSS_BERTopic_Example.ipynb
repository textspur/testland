# %% [markdown]
# <a href="https://colab.research.google.com/github/textspur/testland/blob/main/BIGSSS_BERTopic_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Go to Runtime -> Change runtime type -> Set "Hardware Accelerater" to "GPU" (if not set already)
# ---

# %% [markdown]
# # BERTopic example
# BERTopic is a topic modeling technique that leverages transformers and c-TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions. BERTopic supports all kinds of topic modeling techniques.
#
# More info in the [documentation](https://maartengr.github.io/BERTopic/getting_started/quickstart/quickstart.html), [Github](https://github.com/MaartenGr/BERTopic) and in a [preprint](https://arxiv.org/abs/2203.05794)

# %%
pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.30)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.35)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.30.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.2)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %% [markdown]
# ## Data set
# Newsgroup - The fetch_20newsgroups dataset is a collection of ~18,000 newsgroup documents from 20 different newsgroups

# %%
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
print(docs[676])
print("type of object docs: ", type(docs))
# keep the first half
docs = docs[:len(docs)//2]
print("number of documents: ", len(docs))
# Out:
# I've been wondering about this myself.  The house wiring thing is really
# hokey.  There is no doubt that high pressure ultrasound is annoying, but to
# whom?  Given that these devices have been advertised to be effective against
# everything from insects to rodents to nasty dogs, what is to say that my
# insect repeller won't just annnoy my dog and give me headaches?  Could there
# be that much selectivity in frequencies?  Have there been ANY studies
# on the effects of various pressure levels, bands, and sweep patterns on
# various life forms?
#
# And how effective could they be?  I certainly would not want to tell anyone
# that they are safe from nasty dogs because they were carrying a piezoelectric
# buzzer...
#
# type of object docs:  <class 'list'>
# number of documents:  9423

# %% [markdown]
# ## Run BERTopic

# %% [markdown]
# Use BERTopic(language="multilingual") to select a model that supports 50+ languages.

# %%
from bertopic import BERTopic

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)

# %% [markdown]
# After generating topics and their probabilities, we can access the frequent topics that were generated:

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                              Name  \
# 0       -1   3365                   -1_the_to_of_is
# 1        0    873                0_game_he_team_was
# 2        1    381       1_space_shuttle_launch_nasa
# 3        2    276          2_whatta_cheek_ditto_ass
# 4        3    272     3_key_clipper_encryption_chip
# ..     ...    ...                               ...
# 121    120     11      120_tape_tapes_marker_backup
# 122    121     10      121_w4wg_mail_lan_workgroups
# 123    122     10  122_lock_kryptonite_cable_zipper
# 124    123     10              123_bmw_bmws_r80_moa
# 125    124     10     124_insurance_rates_geico_car
#
#                                         Representation  \
# 0      [the, to, of, is, and, in, that, it, for, this]
# 1    [game, he, team, was, games, play, 10, players...
# 2    [space, shuttle, launch, nasa, the, mission, o...
# 3    [whatta, cheek, ditto, ass, hello, why, hi, ea...
# 4    [key, clipper, encryption, chip, keys, be, gov...
# ..                                                 ...
# 121  [tape, tapes, marker, backup, holes, 250mb, re...
# 122  [w4wg, mail, lan, workgroups, vax, network, ga...
# 123  [lock, kryptonite, cable, zipper, locks, bicyc...
# 124  [bmw, bmws, r80, moa, parts, bike, insurance, ...
# 125  [insurance, rates, geico, car, drivers, 924, f...
#
#                                    Representative_Docs
# 0    [----- Begin Included Message -----\n\nThe fol...
# 1    [Scoring stats for the Swedish NHL players, Ap...
# 2    [Archive-name: space/controversy\nLast-modifie...
# 3    [\n\nDitto,, \n\tWhatta ass!!!!!\n\n, \n \n   ...
# 4    [April 16, 1993\n\nINITIAL EFF ANALYSIS OF CLI...
# ..                                                 ...
# 121  [\n\tGreetings. There are 3 types of warnings ...
# 122  [This may be a simple question but:\n\nWe have...
# 123  [Greetings netters,\n\nSteve writes ... <about...
# 124  [Hi,\n   I'm now in the market for buying a BM...
# 125  [Hey all,\n\n\nI'm looking at buying a new car...
#
# [126 rows x 5 columns]

# %% [markdown]
# ## Visualisation

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4c186ca6-d26d-4494-81ad-c12d6746235e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c186ca6-d26d-4494-81ad-c12d6746235e")) {                    Plotly.newPlot(                        "4c186ca6-d26d-4494-81ad-c12d6746235e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007249313095590201,0.00741789742754877,0.009626583134544285,0.009725829504340913,0.01237810444676795],"y":["games  ","was  ","team  ","he  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008395267631797756,0.008399720761113283,0.009116889061512473,0.009520220965955868,0.017305512725378693],"y":["the  ","nasa  ","launch  ","shuttle  ","space  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.2978720230693953,0.3752476860808569,0.44549478877299276,0.5108311876800158,0.5840511082827969],"y":["hello  ","ass  ","ditto  ","cheek  ","whatta  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.011647481192236055,0.013527285705577652,0.014360903330589044,0.015593622361190345,0.017583526052519532],"y":["keys  ","chip  ","encryption  ","clipper  ","key  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010916501391955137,0.013501573024713482,0.014258501216273983,0.014763557978873111,0.023637701329849124],"y":["jewish  ","arab  ","jews  ","israeli  ","israel  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014407471399129929,0.014705929830775977,0.016170703925066362,0.026769271111155974,0.030782822727520698],"y":["vga  ","drivers  ","video  ","monitor  ","card  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.009867274351234046,0.010278163980514248,0.010296947228149415,0.010866966517367554,0.017949913072285432],"y":["ride  ","my  ","you  ","riding  ","bike  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009729791050499198,0.010587381775631287,0.012882052811994326,0.018838177095503738,0.022583139640956863],"y":["mustang  ","ford  ","engine  ","cars  ","car  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d85 ...

# %% [markdown]
#  -1 refers to all outliers and should typically be ignored. Next, let's take a look at the most frequent topic that was generated, topic 0:

# %%
topic_model.get_topic(0)
# Out:
# [('game', 0.01237810444676795),
#  ('he', 0.009725829504340913),
#  ('team', 0.009626583134544285),
#  ('was', 0.00741789742754877),
#  ('games', 0.007249313095590201),
#  ('play', 0.007128070946973859),
#  ('10', 0.007078644722751718),
#  ('players', 0.0069851367684264755),
#  ('the', 0.006753076026264185),
#  ('his', 0.0066632457304438624)]

# %%
topic_model.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     \n\nI am sure some bashers of Pens fans are pr...      0
# 1     My brother is in the market for a high-perform...      5
# 2     \n\n\n\n\tFinally you said what you dream abou...     -1
# 3     \nThink!\n\nIt's the SCSI card doing the DMA t...     12
# 4     1)    I have an old Jasmine drive which I cann...     -1
# ...                                                 ...    ...
# 9418  \nAssume in this case the usual canard-adversa...      3
# 9419  \n\nIt is a long standing good luck Redwing's ...      0
# 9420  \nWhich translates to 7% not satisfied.  I don...     91
# 9421  \nThe willingness of the majority of the peopl...    111
# 9422  \n}|>  There are two simple procedures for alt...     -1
#
#                                                    Name  \
# 0                                    0_game_he_team_was
# 1                          5_card_monitor_video_drivers
# 2                                       -1_the_to_of_is
# 3                             12_scsi_scsi2_drive_scsi1
# 4                                       -1_the_to_of_is
# ...                                                 ...
# 9418                      3_key_clipper_encryption_chip
# 9419                                 0_game_he_team_was
# 9420                    91_join_doublespace_dos_stacker
# 9421  111_government_libertarians_libertarian_regula...
# 9422                                    -1_the_to_of_is
#
#                                          Representation  \
# 0     [game, he, team, was, games, play, 10, players...
# 1     [card, monitor, video, drivers, vga, windows, ...
# 2       [the, to, of, is, and, in, that, it, for, this]
# 3     [scsi, scsi2, drive, scsi1, drives, ide, contr...
# 4       [the, to, of, is, and, in, that, it, for, this]
# ...                                                 ...
# 9418  [key, clipper, encryption, chip, keys, be, gov...
# 9419  [game, he, team, was, games, play, 10, players...
# 9420  [join, doublespace, dos, stacker, dos6, workgr...
# 9421  [government, libertarians, libertarian, regula...
# 9422    [the, to, of, is, and, in, that, it, for, this]
#
#                                     Representative_Docs  \
# 0     [Scoring stats for the Swedish NHL players, Ap...
# 1     [I have a Radius Precision Color 24x video car...
# 2     [----- Begin Included Message -----\n\nThe fol...
# 3     [The above does not tell the proper story of S...
# 4     [----- Begin Included Message -----\n\nThe fol...
# ...                                                 ...
# 9418  [April 16, 1993\n\nINITIAL EFF ANALYSIS OF CLI...
# 9419  [Scoring stats for the Swedish NHL players, Ap...
# 9420  [\nHe's right ya know.  I've helped to install...
# 9421  [\nI'm afraid that I've lost the thread here. ...
# 9422  [----- Begin Included Message -----\n\nThe fol...
#
#                                             Top_n_words  Probability  \
# 0     game - he - team - was - games - play - 10 - p...          1.0
# 1     card - monitor - video - drivers - vga - windo...          1.0
# 2     the - to - of - is - and - in - that - it - fo...          0.0
# 3     scsi - scsi2 - drive - scsi1 - drives - ide - ...          1.0
# 4     the - to - of - is - and - in - that - it - fo...          0.0
# ...                                                 ...          ...
# 9418  key - clipper - encryption - chip - keys - be ...          1.0
# 9419  game - he - team - was - games - play - 10 - p...          1.0
# 9420  join - doublespace - dos - stacker - dos6 - wo...          1.0
# 9421  government - libertarians - libertarian - regu...          1.0
# 9422  the - to - of - is - and - in - that - it - fo...          0.0
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9418                    False
# 9419                    False
# 9420                    False
# 9421                    False
# 9422                    False
#
# [9423 rows x 8 columns]

# %% [markdown]
# # Reduce topic outliers
# By default, BERTopic generates outliers which is helpful in creating meaningful topic representations. However, you might want to assign every single document to a topic. We can use .reduce_outliers to map some or all outliers to a topic or use are several different ways to reduce outliers.

# %% [markdown]
# ## Assign to existing topics

# %%
# Reduce outliers
reduced_outliers_topics = topic_model.reduce_outliers(docs, topics)

# %%
topic_model.update_topics(docs, topics=reduced_outliers_topics)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                           Name  \
# 0        0    918             0_game_he_team_was
# 1        1    454         1_space_the_shuttle_of
# 2        2    279         2_ypu_hello_why_whatta
# 3        3    426    3_key_encryption_clipper_be
# 4        4    289     4_israel_jews_israeli_arab
# ..     ...    ...                            ...
# 120    120     16    120_tape_tapes_marker_irwin
# 121    121     24      121_w4wg_mail_network_lan
# 122    122     17  122_lock_cable_kryptonite_600
# 123    123     17           123_bmw_bmws_r80_moa
# 124    124     18  124_insurance_geico_rates_car
#
#                                         Representation  \
# 0    [game, he, team, was, 10, games, play, the, pl...
# 1    [space, the, shuttle, of, launch, nasa, and, m...
# 2    [ypu, hello, why, whatta, stereotype, cheek, d...
# 3    [key, encryption, clipper, be, chip, to, the, ...
# 4    [israel, jews, israeli, arab, jewish, of, the,...
# ..                                                 ...
# 120  [tape, tapes, marker, irwin, 16ea, backup, hol...
# 121  [w4wg, mail, network, lan, gateway, workgroups...
# 122  [lock, cable, kryptonite, 600, zipper, locks, ...
# 123  [bmw, bmws, r80, moa, parts, bike, dealer, dod...
# 124  [insurance, geico, rates, car, farm, drivers, ...
#
#                                    Representative_Docs
# 0    [Scoring stats for the Swedish NHL players, Ap...
# 1    [Archive-name: space/controversy\nLast-modifie...
# 2    [\n\nDitto,, \n\tWhatta ass!!!!!\n\n, \n \n   ...
# 3    [April 16, 1993\n\nINITIAL EFF ANALYSIS OF CLI...
# 4    [\n\n"Assuming"? Also: come on, Brad. If we ar...
# ..                                                 ...
# 120  [\n\tGreetings. There are 3 types of warnings ...
# 121  [This may be a simple question but:\n\nWe have...
# 122  [Greetings netters,\n\nSteve writes ... <about...
# 123  [Hi,\n   I'm now in the market for buying a BM...
# 124  [Hey all,\n\n\nI'm looking at buying a new car...
#
# [125 rows x 5 columns]

# %% [markdown]
# ## Change clustering algorithm

# %%
from bertopic import BERTopic
from sklearn.cluster import KMeans

cluster_model = KMeans(n_clusters=50)
topic_model_kmeans = BERTopic(hdbscan_model=cluster_model)
topicsKmeans, probsKmeans = topic_model_kmeans.fit_transform(docs)

topic_model_kmeans.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0       0    358                                     0_of_and_to_is
# 1       1    351                                   1_he_year_the_in
# 2       2    326                               2_window_to_the_this
# 3       3    301                               3_the_israel_of_that
# 4       4    295                              4_car_the_cars_engine
# 5       5    293                               5_key_the_clipper_to
# 6       6    282                                   6_of_is_that_the
# 7       7    279                                 7_the_game_he_team
# 8       8    279                            8_drive_scsi_ide_drives
# 9       9    278                                   9_god_that_is_of
# 10     10    275                           10_card_monitor_video_it
# 11     11    274                           11_cheek_ditto_why_hello
# 12     12    265                                 12_of_the_that_and
# 13     13    251                                 13_bike_you_my_the
# 14     14    250                                  14_bike_the_it_to
# 15     15    241                                15_the_fbi_they_was
# 16     16    237                                16_for_and_with_mac
# 17     17    230                            17_space_the_shuttle_to
# 18     18    225                                   18_for_and_of_in
# 19     19    223                              19_windows_dos_it_the
# 20     20    215                              20_mhz_simms_the_with
# 21     21    204                              21_space_the_of_venus
# 22     22    200                                  22_you_that_to_of
# 23     23    190                              23_sound_for_audio_to
# 24     24    177                                 24_gun_guns_to_the
# 25     25    175                             25_jpeg_image_gif_file
# 26     26    174                        26_windows_os2_for_keyboard
# 27     27    174                             27_president_to_the_we
# 28     28    174                             28_appears_1st_100_art
# 29     29    169                    29_is_openwindows_for_available
# 30     30    161  30_maxaxaxaxaxaxaxaxaxaxaxaxaxaxax_graphics_ph...
# 31     31    156                             31_armenian_the_of_and
# 32     32    138                            32_the_to_government_of
# 33     33    137                                   33_the_to_is_you
# 34     34    132                        34_game_baseball_games_espn
# 35     35    123                     35_professors_oo_university_of
# 36     36    121                             36_modem_tape_port_the
# 37     37    119                        37_printer_fonts_print_font
# 38     38    110                                38_10_period_11_550
# 39     39    109                                39_radar_car_the_is
# 40     40     99                                  40_of_to_that_the
# 41     41     98                              41_cancer_sex_that_of
# 42     42     88                          42_playback_for_to_frames
# 43     43     81                                43_islam_of_the_and
# 44     44     81                               44_entry_file_the_to
# 45     45     80                                   45_for_me_you_to
# 46     46     69                              46_wax_it_paint_wasps
# 47     47     66                     47_morality_moral_objective_is
# 48     48     48                  48_insurance_health_private_drugs
# 49     49     42                 49_ground_conductor_grounding_wire
#
#                                        Representation  \
# 0   [of, and, to, is, the, in, that, patients, it,...
# 1    [he, year, the, in, his, to, hit, was, and, but]
# 2   [window, to, the, this, is, motif, it, on, if,...
# 3   [the, israel, of, that, to, in, and, you, not,...
# 4   [car, the, cars, engine, it, is, for, and, in,...
# 5   [key, the, clipper, to, be, encryption, chip, ...
# 6     [of, is, that, the, to, not, and, it, god, are]
# 7   [the, game, he, team, was, in, to, hockey, and...
# 8   [drive, scsi, ide, drives, controller, disk, t...
# 9   [god, that, is, of, to, the, not, jesus, in, and]
# 10  [card, monitor, video, it, the, for, drivers, ...
# 11  [cheek, ditto, why, hello, hi, tell, each, ver...
# 12   [of, the, that, and, jesus, is, he, in, to, god]
# 13      [bike, you, my, the, to, and, on, it, of, in]
# 14  [bike, the, it, to, oil, and, my, on, for, bikes]
# 15  [the, fbi, they, was, that, fire, batf, to, ko...
# 16  [for, and, with, mac, to, os, the, drive, ram,...
# 17  [space, the, shuttle, to, and, of, for, nasa, ...
# 18  [for, and, of, in, data, graphics, to, the, fr...
# 19  [windows, dos, it, the, have, problem, to, mem...
# 20  [mhz, simms, the, with, motherboard, ram, spee...
# 21  [space, the, of, venus, and, in, for, satellit...
# 22  [you, that, to, of, your, jim, it, not, post, ...
# 23  [sound, for, audio, to, and, the, is, it, with...
# 24   [gun, guns, to, the, that, you, in, of, is, and]
# 25  [jpeg, image, gif, file, images, format, files...
# 26  [windows, os2, for, keyboard, to, dos, is, it,...
# 27  [president, to, the, we, and, that, of, in, th...
# 28  [appears, 1st, 100, art, dos, wolverine, cover...
# 29  [is, openwindows, for, available, and, can, th...
# 30  [maxaxaxaxaxaxaxaxaxaxaxaxaxaxax, graphics, ph...
# 31  [armenian, the, of, and, armenians, were, in, ...
# 32  [the, to, government, of, that, and, people, i...
# 33  [the, to, is, you, of, noise, voltage, it, and...
# 34  [game, baseball, games, espn, the, to, hockey,...
# 35  [professors, oo, university, of, school, to, l...
# 36  [modem, tape, port, the, serial, to, is, for, ...
# 37  [printer, fonts, print, font, deskjet, windows...
# 38    [10, period, 11, 550, 13, 14, 12, pit, det, pp]
# 39  [radar, car, the, is, detector, water, in, it,...
# 40  [of, to, that, the, is, in, not, rights, are, ...
# 41  [cancer, sex, that, of, gay, homosexual, you, ...
# 42  [playback, for, to, frames, and, the, video, p...
# 43  [islam, of, the, and, to, his, in, this, is, t...
# 44  [entry, file, the, to, anonymous, of, is, be, ...
# 45  [for, me, you, to, hotel, if, package, the, pr...
# 46  [wax, it, paint, wasps, to, and, the, ear, bre...
# 47  [morality, moral, objective, is, that, to, you...
# 48  [insurance, health, private, drugs, that, cana...
# 49  [ground, conductor, grounding, wire, neutral, ...
#
#                                   Representative_Docs
# 0   [I can not believe the way this thread on cand...
# 1   [\nYes.  But this is *irrelevant*.  You're tal...
# 2   [Im new to Xlib programming. Im having a probl...
# 3   [THE WHITE HOUSE\n\n                    Office...
# 4   [\n\nMy whole point was not to say that the ca...
# 5   [Hmm, followup on my own posting... Well, who ...
# 6   [=  \n= : [ The discussion begins: why does th...
# 7   [It was unlikely, improbable.  For the Bruins,...
# 8   [I have a 486sx25 computer with a 105 Mg Seaga...
# 9   [Someone sent me this FAQ by E-mail and I post...
# 10  [Experiences with Diamond Viper VLB video card...
# 11  [of  \nWhy  \n\n, \n\nDitto,, \n \n           ...
# 12  [----- Begin Included Message -----\n\nThe fol...
# 13  [Re: Waving...\n\nI must say, that the courtes...
# 14  [Anyone, \n\n    I am a serious motorcycle ent...
# 15  [This was posted by Lyn Bates to the firearms-...
# 16  [\n\n    What phony names? My name is clearly ...
# 17  [\n\nHa!\n\n\nWatch me. It flies. It lands. It...
# 18  [Archive-name: graphics/resources-list/part1\n...
# 19  [Hi Netters,\n\nAs promised, here are the summ...
# 20  [To those interested in the new ATI Ultra Card...
# 21  [Archive-name: space/acronyms\nEdition: 8\n\nA...
# 22  [}>}>}(a) out of context;\n}>}>Must have misse...
# 23  [Well, I've come into some money and want to b...
# 24  [\nSaying "hopefully the effect of policy X wi...
# 25  [I have posted DISP140.ZIP to alt.binaries.pic...
# 26  [I have been posting monthly "how-to-setup a S...
# 27  [Here is a press release from the White House....
# 28  [OK.  Instead of holding an auction, I have de...
# 29  [Archive-name: x-faq/part3\nLast-modified: 199...
# 30  [molecules has evolved from an esoteric academ...
# 31  [Accounts of Anti-Armenian Human Right Violati...
# 32  [\nIt appears it is time that this article (or...
# 33  [Well, actually not quite. Both Radar and Radi...
# 34  [\nUntil six or seven years ago I was an enthu...
# 35  [\n\nAnd it is a damn good thing that she did ...
# 36  [FOR SALE:\n\nAT&T Dataport Internal 14.4K Fax...
# 37  [Printer model and specification:\n\nCanon CLC...
# 38  [NHL RESULTS FOR GAMES PLAYED 4/14/93.\n\n----...
# 39  [Here's one I hope some knowledgeable readers ...
# 40  [\n\nWell, I've said that when an innocent per...
# 41  [# #I used to think that homosexuals were OK -...
# 42  [OK, with all the discussion about observed pl...
# 43  [\nOnce the Rushdie situation exploded into th...
# 44  [Archive-name: net-privacy/part1\nLast-modifie...
# 45  [: While not exactly a service incident, I had...
# 46  [since at least one other person was intereste...
# 47  [\n\n\nI think that you are changing the meani...
# 48  [\nOur doctors' monopoly is exactly the same a...
# 49  [\nNot according to the NEC nor the CEC, as ex...

# %%
topic_model_kmeans.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     \n\nI am sure some bashers of Pens fans are pr...      7
# 1     My brother is in the market for a high-perform...     10
# 2     \n\n\n\n\tFinally you said what you dream abou...     31
# 3     \nThink!\n\nIt's the SCSI card doing the DMA t...      8
# 4     1)    I have an old Jasmine drive which I cann...      8
# ...                                                 ...    ...
# 9418  \nAssume in this case the usual canard-adversa...      5
# 9419  \n\nIt is a long standing good luck Redwing's ...      7
# 9420  \nWhich translates to 7% not satisfied.  I don...     19
# 9421  \nThe willingness of the majority of the peopl...     32
# 9422  \n}|>  There are two simple procedures for alt...      4
#
#                           Name  \
# 0           7_the_game_he_team
# 1     10_card_monitor_video_it
# 2       31_armenian_the_of_and
# 3      8_drive_scsi_ide_drives
# 4      8_drive_scsi_ide_drives
# ...                        ...
# 9418      5_key_the_clipper_to
# 9419        7_the_game_he_team
# 9420     19_windows_dos_it_the
# 9421   32_the_to_government_of
# 9422     4_car_the_cars_engine
#
#                                          Representation  \
# 0     [the, game, he, team, was, in, to, hockey, and...
# 1     [card, monitor, video, it, the, for, drivers, ...
# 2     [armenian, the, of, and, armenians, were, in, ...
# 3     [drive, scsi, ide, drives, controller, disk, t...
# 4     [drive, scsi, ide, drives, controller, disk, t...
# ...                                                 ...
# 9418  [key, the, clipper, to, be, encryption, chip, ...
# 9419  [the, game, he, team, was, in, to, hockey, and...
# 9420  [windows, dos, it, the, have, problem, to, mem...
# 9421  [the, to, government, of, that, and, people, i...
# 9422  [car, the, cars, engine, it, is, for, and, in,...
#
#                                     Representative_Docs  \
# 0     [It was unlikely, improbable.  For the Bruins,...
# 1     [Experiences with Diamond Viper VLB video card...
# 2     [Accounts of Anti-Armenian Human Right Violati...
# 3     [I have a 486sx25 computer with a 105 Mg Seaga...
# 4     [I have a 486sx25 computer with a 105 Mg Seaga...
# ...                                                 ...
# 9418  [Hmm, followup on my own posting... Well, who ...
# 9419  [It was unlikely, improbable.  For the Bruins,...
# 9420  [Hi Netters,\n\nAs promised, here are the summ...
# 9421  [\nIt appears it is time that this article (or...
# 9422  [\n\nMy whole point was not to say that the ca...
#
#                                             Top_n_words  \
# 0     the - game - he - team - was - in - to - hocke...
# 1     card - monitor - video - it - the - for - driv...
# 2     armenian - the - of - and - armenians - were -...
# 3     drive - scsi - ide - drives - controller - dis...
# 4     drive - scsi - ide - drives - controller - dis...
# ...                                                 ...
# 9418  key - the - clipper - to - be - encryption - c...
# 9419  the - game - he - team - was - in - to - hocke...
# 9420  windows - dos - it - the - have - problem - to...
# 9421  the - to - government - of - that - and - peop...
# 9422  car - the - cars - engine - it - is - for - an...
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9418                    False
# 9419                    False
# 9420                    False
# 9421                    False
# 9422                    False
#
# [9423 rows x 7 columns]

# %% [markdown]
# # Guided topic model

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))["data"]
docs = docs[:len(docs)//2]

seed_topic_list = [["drug", "cancer", "drugs", "doctor"],
                   ["windows", "drive", "dos", "file"],
                   ["space", "launch", "orbit", "lunar"]]

topic_model = BERTopic(seed_topic_list=seed_topic_list)
topics, probs = topic_model.fit_transform(docs)

# After generating topics and their probabilities, we can access the frequent topics that were generated:

topic_model.get_topic_info()
# Out:
#      Topic  Count                                    Name  \
# 0       -1   3310                        -1_to_the_is_and
# 1        0    871                      0_game_he_team_was
# 2        1    452              1_space_launch_the_shuttle
# 3        2    360       2_cancer_medical_patients_disease
# 4        3    276           3_idjits_whatta_cheek_dancing
# ..     ...    ...                                     ...
# 109    108     11  108_book_commentary_books_introduction
# 110    109     11             109_context_jim_stephen_trm
# 111    110     11   110_shaft_wheelie_wheelies_shaftdrive
# 112    111     11        111_turn_monitor_electricity_off
# 113    112     10                   112_prk_cornea_rk_eye
#
#                                         Representation  \
# 0       [to, the, is, and, of, you, it, for, in, that]
# 1    [game, he, team, was, the, games, 10, play, pl...
# 2    [space, launch, the, shuttle, orbit, of, nasa,...
# 3    [cancer, medical, patients, disease, doctor, o...
# 4    [idjits, whatta, cheek, dancing, ditto, ass, w...
# ..                                                 ...
# 109  [book, commentary, books, introduction, harper...
# 110  [context, jim, stephen, trm, telepathy, you, q...
# 111  [shaft, wheelie, wheelies, shaftdrive, chain, ...
# 112  [turn, monitor, electricity, off, computer, co...
# 113  [prk, cornea, rk, eye, vision, eyeball, detach...
#
#                                    Representative_Docs
# 0    [\nIf I have a habit that I really want to bre...
# 1    [Scoring stats for the Swedish NHL players, Ap...
# 2    [Archive-name: space/astronaut\nLast-modified:...
# 3    [------------- cut here -----------------\nUni...
# 4    [\n \n                                        ...
# ..                                                 ...
# 109  [From time to time I have made reference to a ...
# 110  [\n(1)  Stephen said you took a quote out of c...
# 111  [: \n: >I bought it, I tried it:\n: \n: >It is...
# 112  [\nthis is a bad idea. my machine is on 24 hou...
# 113  [I am quite near sighted.\n\nI've recently rec...
#
# [114 rows x 5 columns]

# %%
similar_topics, similarity = topic_model.find_topics("lunar", top_n=5)
topic_model.get_topic(similar_topics[0])
# Out:
# [('space', 0.02001896230657995),
#  ('launch', 0.010607673512321716),
#  ('the', 0.009232033091110594),
#  ('shuttle', 0.009165128058046944),
#  ('orbit', 0.008653373295278856),
#  ('of', 0.008154579327037498),
#  ('nasa', 0.007982041631793177),
#  ('mission', 0.007496629788725885),
#  ('and', 0.007192128154726913),
#  ('to', 0.007050238205802654)]

# %%
topic_model.visualize_barchart(n_words= 8, top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ee994a58-fe12-4bf9-9cd2-acc69302f9b3" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee994a58-fe12-4bf9-9cd2-acc69302f9b3")) {                    Plotly.newPlot(                        "ee994a58-fe12-4bf9-9cd2-acc69302f9b3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007224436858218465,0.00724880851286303,0.007368628104931046,0.007381670561917717,0.007890254514064388,0.00980263402230959,0.010206039421470576,0.012710296976857782],"y":["play  ","10  ","games  ","the  ","was  ","team  ","he  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007496629788725885,0.007982041631793177,0.008154579327037498,0.008653373295278856,0.009165128058046944,0.009232033091110594,0.010607673512321716,0.02001896230657995],"y":["mission  ","nasa  ","of  ","orbit  ","shuttle  ","the  ","launch  ","space  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.007771763248253179,0.008112326568989072,0.008784886728599497,0.008904071529916112,0.009093519248459997,0.011604684100719177,0.011924685099590297,0.017198064804386386],"y":["drug  ","and  ","of  ","doctor  ","disease  ","patients  ","medical  ","cancer  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.26865231549724217,0.2719495332696189,0.33696912277921015,0.39896497755575344,0.4265872398599478,0.4566191267181201,0.5212266950163108,0.5619958868450742],"y":["hello  ","why  ","ass  ","ditto  ","dancing  ","cheek  ","whatta  ","idjits  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010118642219103878,0.010289460564471184,0.011170376348888365,0.011636867974111946,0.01441316884041716,0.014886171406471948,0.01635811155218022,0.017441859105467267],"y":["escrow  ","government  ","be  ","keys  ","chip  ","encryption  ","clipper  ","key  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.010739887257020403,0.011560233144936025,0.013684521829439382,0.014841184698657452,0.015501042148747283,0.016559157495227413,0.029478481848938764,0.03158712985021845],"y":["cards  ","monitors  ","windows  ","drivers  ","vga  ","video  ","monitor  ","card  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010474648916695329,0.010554994567456528,0.011649574326603889,0.011806336728759009,0.015067751037807385,0.01518149983834101,0.01619131631768839,0.026623149959930942],"y":["palestinian  ","jewish  ","ed  ","arabs  ","arab  ","jews  ","israeli  ","israel  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.010557082424256523,0.010935291049944574,0.01153954755410829,0.011942653476751563,0.012077830726884193,0.012380036481488998,0.013126972359184629,0.017529309879867547],"y":["riding  ","helmet  ","cop  ","you  ","lane  ","my  ","ride  ","bike  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014303118752747273,0.016417661938786392,0.017409611418807744,0.018002219801251603,0.02025748110978726,0.020775966733867713,0.02134638621272162,0.022433271058342828],"y":["menu  ","program  ","gif  ","tiff  ","format  ","image  ","file  ","files  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010476070720970542,0.010559397248056835,0.010885630332105456,0.010954683795716702,0.012243019807691156,0.014635269715178536,0.018044597290517876,0.02074539367827569],"y":["azerbaijan  ","the  ","of  ","and  ","turkish  ","were  ","armenians  ","armenian  "],"type":"bar","xaxis":"x10","yaxis": ...

# %%
topic_model.get_topic(0)
topic_model.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     \n\nI am sure some bashers of Pens fans are pr...      0
# 1     My brother is in the market for a high-perform...      5
# 2     \n\n\n\n\tFinally you said what you dream abou...      9
# 3     \nThink!\n\nIt's the SCSI card doing the DMA t...     -1
# 4     1)    I have an old Jasmine drive which I cann...     -1
# ...                                                 ...    ...
# 9418  \nAssume in this case the usual canard-adversa...      4
# 9419  \n\nIt is a long standing good luck Redwing's ...      0
# 9420  \nWhich translates to 7% not satisfied.  I don...     -1
# 9421  \nThe willingness of the majority of the peopl...    106
# 9422  \n}|>  There are two simple procedures for alt...     -1
#
#                                                    Name  \
# 0                                    0_game_he_team_was
# 1                              5_card_monitor_video_vga
# 2                     9_armenian_armenians_were_turkish
# 3                                      -1_to_the_is_and
# 4                                      -1_to_the_is_and
# ...                                                 ...
# 9418                      4_key_clipper_encryption_chip
# 9419                                 0_game_he_team_was
# 9420                                   -1_to_the_is_and
# 9421  106_government_libertarians_libertarian_regula...
# 9422                                   -1_to_the_is_and
#
#                                          Representation  \
# 0     [game, he, team, was, the, games, 10, play, pl...
# 1     [card, monitor, video, vga, drivers, windows, ...
# 2     [armenian, armenians, were, turkish, and, of, ...
# 3        [to, the, is, and, of, you, it, for, in, that]
# 4        [to, the, is, and, of, you, it, for, in, that]
# ...                                                 ...
# 9418  [key, clipper, encryption, chip, keys, be, gov...
# 9419  [game, he, team, was, the, games, 10, play, pl...
# 9420     [to, the, is, and, of, you, it, for, in, that]
# 9421  [government, libertarians, libertarian, regula...
# 9422     [to, the, is, and, of, you, it, for, in, that]
#
#                                     Representative_Docs  \
# 0     [Scoring stats for the Swedish NHL players, Ap...
# 1     [Has anyone connected a high-res, fixed freque...
# 2     [\n\nA typical Armenian revisionist. As in the...
# 3     [\nIf I have a habit that I really want to bre...
# 4     [\nIf I have a habit that I really want to bre...
# ...                                                 ...
# 9418  [Hmm, followup on my own posting... Well, who ...
# 9419  [Scoring stats for the Swedish NHL players, Ap...
# 9420  [\nIf I have a habit that I really want to bre...
# 9421  [\nI'm afraid that I've lost the thread here. ...
# 9422  [\nIf I have a habit that I really want to bre...
#
#                                             Top_n_words  Probability  \
# 0     game - he - team - was - the - games - 10 - pl...     1.000000
# 1     card - monitor - video - vga - drivers - windo...     1.000000
# 2     armenian - armenians - were - turkish - and - ...     0.943913
# 3     to - the - is - and - of - you - it - for - in...     0.000000
# 4     to - the - is - and - of - you - it - for - in...     0.000000
# ...                                                 ...          ...
# 9418  key - clipper - encryption - chip - keys - be ...     1.000000
# 9419  game - he - team - was - the - games - 10 - pl...     1.000000
# 9420  to - the - is - and - of - you - it - for - in...     0.000000
# 9421  government - libertarians - libertarian - regu...     1.000000
# 9422  to - the - is - and - of - you - it - for - in...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9418                    False
# 9419                    False
# 9420                    False
# 9421                    False
# 9422                    False
#
# [9423 rows x 8 columns]

# %% [markdown]
# # South Park example

# %%
import pandas as pd

# Only first 5 episodes
urls = ["https://raw.githubusercontent.com/BobAdamsEE/SouthParkData/master/by-season/Season-{}.csv".format(i) for i in range(1, 20)]


south_park_data = pd.concat([pd.read_csv(url) for url in urls[0:5]])
south_park_data.head()
# Out:
#    Season  Episode Character  \
# 0       1        1      Boys
# 1       1        1      Kyle
# 2       1        1       Ike
# 3       1        1      Kyle
# 4       1        1   Cartman
#
#                                                 Line
# 0   School day, school day, teacher's golden ru...\n
# 1  Ah, damn it! My little brother's trying to fol...
# 2                                     Zeeponanner.\n
# 3          Ike, you can't come to school with me. \n
# 4                  Yeah, go home you little dildo.\n

# %%
main_characters = ["Cartman", "Kyle", "Stan", "Kenny"]
south_park_data = south_park_data[south_park_data['Character'].isin(main_characters)]
south_park_data.head()
# Out:
#    Season  Episode Character  \
# 1       1        1      Kyle
# 3       1        1      Kyle
# 4       1        1   Cartman
# 5       1        1      Kyle
# 6       1        1      Stan
#
#                                                 Line
# 1  Ah, damn it! My little brother's trying to fol...
# 3          Ike, you can't come to school with me. \n
# 4                  Yeah, go home you little dildo.\n
# 5             Dude, don't call my brother a dildo!\n
# 6                                  What's a dildo?\n

# %%
south_park_docs = south_park_data['Line']
south_park_docs[1]
# Out:
# 1    Ah, damn it! My little brother's trying to fol...
# 1                                              What?\n
# Name: Line, dtype: object

# %%
sp_topic_model = BERTopic()
sp_topics, sp_probs = sp_topic_model.fit_transform(south_park_docs)

# %%
# After generating topics and their probabilities, we can access the frequent topics that were generated:
sp_topic_model.get_topic_info()
# Out:
#      Topic  Count                                Name  \
# 0       -1   2934                -1_cartman_it_to_the
# 1        0    167           0_kyle_kyles_bitch_kidney
# 2        1    151           1_jesus_lord_confess_sins
# 3        2    142                   2_him_hes_he_dead
# 4        3    136               3_dad_mom_father_dads
# ..     ...    ...                                 ...
# 249    248     10  248_cirque_quintuplets_du_cheville
# 250    249     10         249_house_size_houses_folks
# 251    250     10       250_hurry_hammer_faster_catch
# 252    251     10                    251_what_about__
# 253    252     10        252_video_game_playing_games
#
#                                         Representation  \
# 0    [cartman, it, to, the, you, your, we, and, hav...
# 1    [kyle, kyles, bitch, kidney, brother, friend, ...
# 2    [jesus, lord, confess, sins, church, crackers,...
# 3    [him, hes, he, dead, gone, found, forget, yet,...
# 4    [dad, mom, father, dads, my, nyah, nurection, ...
# ..                                                 ...
# 249  [cirque, quintuplets, du, cheville, mayors, ro...
# 250  [house, size, houses, folks, storm, tail, lobs...
# 251  [hurry, hammer, faster, catch, weve, come, qui...
# 252                      [what, about, , , , , , , , ]
# 253  [video, game, playing, games, myself, quality,...
#
#                                    Representative_Docs
# 0    [...Okay Cartman, what do you want this time?\...
# 1                [Kyle! Kyle!\n, I'm Kyle.\n, Kyle?\n]
# 2    [Jesus, ix-nay on the ool-schay.\n, Well, you ...
# 3    [Do you see him?\n, Yeah. Do you know him?\n, ...
# 4                   [Dad.\n, Mom! Dad!\n, Mom! Dad!\n]
# ..                                                 ...
# 249  [Will you guys be in our Cirque du Celville?\n...
# 250  [Is this the right house?\n, Oh, come on, Toke...
# 251  [You guys, we have to hurry!\n, Hurry up, you ...
# 252                       [What?\n, What?\n, What??\n]
# 253  [Anyway, that will give me plenty of time play...
#
# [254 rows x 5 columns]

# %% [markdown]
# ## Remove stopwords and infrequent terms
#
# One component of BERTopic is the CountVectorizer and c-TF-IDF calculation. Together, they are responsible for creating the topic representations and luckily can be quite flexible in parameter tuning.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Fine-tune topic representations after training BERTopic
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3), min_df=10)
sp_topic_model.update_topics(south_park_docs, vectorizer_model=vectorizer_model)

# %%
sp_topic_model.get_topic_info()
# Out:
#      Topic  Count                             Name  \
# 0       -1   2934     -1_cartman_isnt_stupid_kenny
# 1        0    167         0_kyle_bitch_friend_shes
# 2        1    151           1_jesus_night_god_walk
# 3        2    142         2_hes_dead_dude hes_gone
# 4        3    136           3_dad_mom_mother_leave
# ..     ...    ...                              ...
# 249    248     10         248_havent_hoh_came_took
# 250    249     10     249_house_room_times_outside
# 251    250     10  250_hurry_weve gotta_quick_weve
# 252    251     10                          251____
# 253    252     10       252_game_play_rest_brought
#
#                                         Representation  \
# 0    [cartman, isnt, stupid, kenny, cartmans, thats...
# 1    [kyle, bitch, friend, shes, looking, best, soo...
# 2    [jesus, night, god, walk, hell, needs, eat, sa...
# 3    [hes, dead, dude hes, gone, dude think, guy, l...
# 4    [dad, mom, mother, leave, whos, moms, happen, ...
# ..                                                 ...
# 249  [havent, hoh, came, took, listen, stay, start,...
# 250  [house, room, times, outside, food, ive got, h...
# 251  [hurry, weve gotta, quick, weve, wed, course, ...
# 252                               [, , , , , , , , , ]
# 253  [game, play, rest, brought, alright alright, h...
#
#                                    Representative_Docs
# 0    [...Okay Cartman, what do you want this time?\...
# 1                [Kyle! Kyle!\n, I'm Kyle.\n, Kyle?\n]
# 2    [Jesus, ix-nay on the ool-schay.\n, Well, you ...
# 3    [Do you see him?\n, Yeah. Do you know him?\n, ...
# 4                   [Dad.\n, Mom! Dad!\n, Mom! Dad!\n]
# ..                                                 ...
# 249  [Will you guys be in our Cirque du Celville?\n...
# 250  [Is this the right house?\n, Oh, come on, Toke...
# 251  [You guys, we have to hurry!\n, Hurry up, you ...
# 252                       [What?\n, What?\n, What??\n]
# 253  [Anyway, that will give me plenty of time play...
#
# [254 rows x 5 columns]

# %% [markdown]
# ## Topics per Class

# %%
classes = south_park_data["Character"]

# %%
topics_per_class = sp_topic_model.topics_per_class(south_park_docs, classes=classes)

# %%
sp_topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="260b1051-29f0-4be2-944a-f27e678bbf05" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("260b1051-29f0-4be2-944a-f27e678bbf05")) {                    Plotly.newPlot(                        "260b1051-29f0-4be2-944a-f27e678bbf05",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: kyle, friend, bitch, best, youd","<b>Topic 0</b><br>Words: kyle, bitch, shes, friend, hair","<b>Topic 0</b><br>Words: kyle, telling, tried, crazy, head","<b>Topic 0</b><br>Words: kyle, bus, little, looking, know think"],"marker":{"color":"#E69F00"},"name":"0_kyle_bitch_friend_shes","orientation":"h","visible":true,"x":[78,72,7,10],"y":["Stan","Cartman","Kenny","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: jesus, goin, needs, save, told","<b>Topic 1</b><br>Words: jesus, night, walk, god, thank","<b>Topic 1</b><br>Words: needs, jesus, kicks, eat, god"],"marker":{"color":"#56B4E9"},"name":"1_jesus_night_god_walk","orientation":"h","visible":"legendonly","x":[52,74,25],"y":["Stan","Cartman","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: hes, dude hes, gone, dude think, dead","<b>Topic 2</b><br>Words: dead, hes, dumbass, heard, left","<b>Topic 2</b><br>Words: hes, dude hes, gone, dead, brought"],"marker":{"color":"#009E73"},"name":"2_hes_dead_dude hes_gone","orientation":"h","visible":"legendonly","x":[63,25,54],"y":["Stan","Cartman","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: dad, mom, moms, leave, youve got","<b>Topic 3</b><br>Words: mom, dad, mother, whos, happen","<b>Topic 3</b><br>Words: dad, mom, ask, world, mother"],"marker":{"color":"#F0E442"},"name":"3_dad_mom_mother_leave","orientation":"h","visible":"legendonly","x":[49,60,27],"y":["Stan","Cartman","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: stan, meet, earth, wendy, aw","<b>Topic 4</b><br>Words: stan, kyle, telling, anybody, wendy","<b>Topic 4</b><br>Words: stan, im going, screw, does, home","<b>Topic 4</b><br>Words: stan, kill, look like, best, wendy"],"marker":{"color":"#D55E00"},"name":"4_stan_wendy_friend_kill","orientation":"h","visible":"legendonly","x":[8,59,4,60],"y":["Stan","Cartman","Kenny","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 5</b><br>Words: dollars, money, win, work, throw","<b>Topic 5</b><br>Words: dollars, money, boy, start, bet","<b>Topic 5</b><br>Words: dollars, money, bet, make, win","<b>Topic 5</b><br>Words: money, dollars, bet, hear, throw"],"marker":{"color":"#0072B2"},"name":"5_dollars_money_bet_make","orientation":"h","visible":"legendonly","x":[22,58,4,29],"y":["Stan","Cartman","Kenny","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: fat, fatass, boy, shut, bitch","<b>Topic 6</b><br>Words: fat, fatass, tried, shut, im just","<b>Topic 6</b><br>Words: fatass, fat, shut, boy, job"],"marker":{"color":"#CC79A7"},"name":"6_fat_fatass_shut_boy","orientation":"h","visible":"legendonly","x":[35,28,49],"y":["Stan","Cartman","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 7</b><br>Words: cartman, cartmans, talking, happened, actually","<b>Topic 7</b><br>Words: ha, cartman, damn, cartmans, stupid","<b>Topic 7</b><br>Words: fuckin, room, cartmans, stupid, ass","<b>Topic 7</b><br>Words: cartman, cartmans, talking, dont know, care"],"marker":{"color":"#E69F00"},"name":"7_cartman_cartmans_ha_talking","orientation":"h","visible":"legendonly","x":[52,2,1,47],"y":["Stan","Cartman","Kenny","Kyle"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 8</b><br>Words: chef, talk, trouble, wouldnt, gotta","<b>Topic 8</b><br>Words: chef, thanks, screw, sc ...

# %% [markdown]
# # Bigger Picture
#
#
#
# *   BERTopic is a topic modeling technique that uses transformers
# *   Mostly it allows for easily interpretable topics
# *   BERTopic generates document embedding with pre-trained transformer-based language models.
#
# *   BERTopic supports all kinds of topic modeling techniques. Check out the documentation and find the right settings for your usecase
#
# https://maartengr.github.io/BERTopic/getting_started/quickstart/quickstart.html
#
# https://github.com/MaartenGr/BERTopic
